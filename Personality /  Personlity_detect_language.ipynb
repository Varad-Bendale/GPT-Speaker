# %% [markdown]
# okay in here see what we got is like listen we got all the esr and fsr all the things we are predicting all the things in here now the clear issue hewre is like see it is predicting the new token itself but we need like the frequiency of the new words the next predicted token is there but we really need the frequncy understanding in here now see listen about the few personlity worrds umm i think we keep it aside and look for the tjing for further part alright so now the thing is we have the thing we got out personlity trained as the person we have al lthe things are per the common personlities we got cool we got these thing now clear part is how to get the freqincies from the vqvae cool now about retireveing the frequencies so now cool thing is we need to update the cnn with like the nn funtion cause it needs the thing for like backtracking makes it better simply 1 thing and next thing we need a backtracking for the vqvae as well so vqvae decoder needs to be done and the code book size needs to be higher much higher to catch all the frequencies simply

# %% [markdown]
# okay listen the upper personlity just gives us the thing for the how the things are spoken its like you give it the speech it just modifys it just for the text but what about the order or the spavcce taken or few of the habits or maybe the normal asss text which comes out from chastgpt it just blank so how about a system which like tqakes up he thing and and then modifys it as per the person speaking or maybe like the human not lie normal ass chatgpt thng

# %% [markdown]
# we are using the below mentioned dataset  for the thing okay see now the real issues i saw was na like when we liek take the human version of things and then take the formal version of things na the entire wordings is fine we can atleast do something of it but the change in the words are hueg and then understanding the whole difference is pretty damn hallucination for the thing so i have an idea lets just take out the ollama the free model we have see it have all the meaning of the thing like suppose like 'you free tonight' and 'are you able to accompany today night' like this see the vocabulary is the issue right so we just need to liek undersrtand which set of the words needs to be used in here and even if we get ti we need to rephrase it better dont i so now i think the freezing the ollama model and then training on top of it would be way better for the stuff isnt it and for production level this si kinda important so probably i would be using the same wayy for wayy more of the things it would be wayy better

# %% [markdown]
# ?? okay see few things i want future me to think is like see we are training on basis of the the freidns okay and on basis on the ollama on the datset of the freinds now there are hell lot of combinartions of personlity in liek people okay so like first of all undersrtanding it and then choosing the type of the vocabulary for all type of the personlity is reral thing which i think needs some thinking liek as per the changing personlity it takes up the thing aslo see we need full of the personlity so not just this much look into liek umm like how offtopic person can go on what context of the speech are they connected are they not something like those factors have a look abnd most important on mixture of opposite of the personlity or rather nany mixtures of the personlities how the tthing would be there okay yeah have a understanding in it i feel so
